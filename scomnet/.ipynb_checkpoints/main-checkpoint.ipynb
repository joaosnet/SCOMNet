# %%
import pandas as pd
import numpy as np
import random
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

import tensorflow_federated as tff

import nest_asyncio
nest_asyncio.apply()

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K

# %%
def unique(list1):       
    list_set = set(list1) 
    unique_list = (list(list_set)) 
    unique_list.sort()
    return unique_list

def create_userids( df ):
    array = df.values
    y = array[:, -1]
    return unique( y )

# %%
def split_dataframe(df):
    RANDOM_STATE = 11235
    
    userids = create_userids(df)
    nbclasses = len(userids)    
    array = df.values
    nsamples, nfeatures = array.shape
    nfeatures = nfeatures -1 
    X = array[:,0:nfeatures]
    y = array[:,-1]
    
    enc = OneHotEncoder()
    enc.fit(y.reshape(-1,1))
    y = enc.transform(y.reshape(-1, 1)).toarray()
    X = X.reshape(-1, 128, 3)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=RANDOM_STATE)
    
    mini_batch_size = int(min(X_train.shape[0]/10, 32))
        
    X_train = np.asarray(X_train).astype(np.float32)
    X_val = np.asarray(X_val).astype(np.float32)
    
    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))

    BATCH_SIZE = mini_batch_size
    SHUFFLE_BUFFER_SIZE = 100
    
    train_ds = train_ds.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
    val_ds = val_ds.batch(BATCH_SIZE)
    
    return train_ds, val_ds, X_test, y_test, nbclasses

# %%
def load_data():
    screens = ['Focus', 'Mathisis', 'Memoria', 'Reacton', 'Speedy']
    screens_code = ['1', '2', '3', '4', '5']

    base_path = "C:/Users/SouthSystem/Federated Learning/DataBioCom/data"
    phone_accel_file_paths = []

    for directories, subdirectories, files in os.walk(base_path):
        for filename in files:
            if "accel" in filename:
                phone_accel_file_paths.append(f"{base_path}/accel/{filename}")

    data = pd.concat(map(pd.read_csv, phone_accel_file_paths))
    users = data['player_id'].unique()
    
    train_set, user_list = split_data(data, users)
    train_set = np.array([np.array(x) for x in train_set]) 
    train_set_join = train_set.reshape(train_set.shape[0], 384)
    data_join = pd.DataFrame(train_set_join)
    data_join['user'] = user_list
    
    train_ds, val_ds, X_test, y_test, n = split_dataframe(data_join)
    
    return train_ds, val_ds, X_test, y_test, n
    
def split_data(data, users):
    user_list = []
    train = []
    frame_size = 128
    step = 50

    for user in users:
        data_user = data[data['player_id']==user]  
        data_user = data_user.iloc[:,[0,1,2]]
        for w in range(0, data_user.shape[0] - frame_size, step):
            end = w + frame_size        
            frame = data_user.iloc[w:end,[0, 1, 2]]        
            train.append(frame)
            user_list.append(user)

    return train, user_list

# %%
def get_datasets():
    train_dataset, validation_dataset, X_test, y_test, n = load_data()
    return train_dataset, validation_dataset, X_test, y_test, n

# %%
def centralized_training_loop(train_dataset, validation_dataset, X_test, y_test, nbclasses, input_shape = (128, 3), num_filters = 128):
    input_layer = keras.layers.Input(input_shape) 

    conv1 = keras.layers.Conv1D(filters=num_filters, kernel_size=8, padding='same')(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.Activation(activation='relu')(conv1)

    conv2 = keras.layers.Conv1D(filters=2*num_filters, kernel_size=5, padding='same')(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.Activation('relu')(conv2)

    conv3 = keras.layers.Conv1D(num_filters, kernel_size=3,padding='same')(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.Activation('relu')(conv3)

    gap_layer = keras.layers.GlobalAveragePooling1D()(conv3)
    output_layer = keras.layers.Dense(nbclasses, activation='softmax')(gap_layer)
    
    model = keras.models.Model(inputs=input_layer, outputs=output_layer)
    
    learning_rate = 0.0001
    cb = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=50, min_lr=learning_rate)
    
    precision = tf.keras.metrics.Precision(name='precision')
    recall = tf.keras.metrics.Recall(name='recall')
    model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.Adam(), metrics=['categorical_accuracy', precision, recall]) 
    
    model.summary()
    
    EPOCHS = 30
    
    hist = model.fit(train_dataset, 
                  epochs=EPOCHS,
                  verbose=True, 
                  validation_data=validation_dataset, 
                  callbacks=cb)
    
    hist_df = pd.DataFrame(hist.history) 
    
    validation_metrics = model.evaluate(validation_dataset, return_dict=True)
    print("Evaluating validation metrics")
    for m in model.metrics:
        print(f"\t{m.name}: {validation_metrics[m.name]:.4f}")        
        
    # EVALUATION 
    X_test = np.asarray(X_test).astype(np.float32)    
    y_true = np.argmax( y_test, axis=1)
    y_pred = np.argmax( model.predict(X_test), axis=1)
    accuracy = accuracy_score(y_true, y_pred)     
    print(accuracy)

# %%
def centralized_pipeline():
    train_dataset, validation_dataset, X_test, y_test, n = get_datasets()
    centralized_training_loop(train_dataset, validation_dataset, X_test, y_test, n)

# %%
centralized_pipeline()
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 3)]          0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 128, 128)          3200
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128, 128)          512
# _________________________________________________________________
# activation_12 (Activation)   (None, 128, 128)          0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 128, 256)          164096
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128, 256)          1024
# _________________________________________________________________
# activation_13 (Activation)   (None, 128, 256)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 128, 128)          98432
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128, 128)          512
# _________________________________________________________________
# activation_14 (Activation)   (None, 128, 128)          0
# _________________________________________________________________
# global_average_pooling1d_4 ( (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                3870
# =================================================================
# Total params: 271,646
# Trainable params: 270,622
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/30
# 1505/1505 [==============================] - 166s 111ms/step - loss: 1.6477 - categorical_accuracy: 0.4871 - precision: 0.6468 - recall: 0.2802 - val_loss: 1.4550 - val_categorical_accuracy: 0.5418 - val_precision: 0.7385 - val_recall: 0.3419
# Epoch 2/30
# 1505/1505 [==============================] - 164s 109ms/step - loss: 1.5021 - categorical_accuracy: 0.5187 - precision: 0.6798 - recall: 0.3340 - val_loss: 1.3782 - val_categorical_accuracy: 0.5565 - val_precision: 0.7234 - val_recall: 0.3778
# Epoch 3/30
# 1505/1505 [==============================] - 162s 108ms/step - loss: 1.4326 - categorical_accuracy: 0.5402 - precision: 0.6995 - recall: 0.3652 - val_loss: 1.3482 - val_categorical_accuracy: 0.5598 - val_precision: 0.7366 - val_recall: 0.4115
# Epoch 4/30
# 1505/1505 [==============================] - 166s 110ms/step - loss: 1.3784 - categorical_accuracy: 0.5550 - precision: 0.7135 - recall: 0.3896 - val_loss: 1.2409 - val_categorical_accuracy: 0.5947 - val_precision: 0.7614 - val_recall: 0.4516
# Epoch 5/30
# 1505/1505 [==============================] - 166s 110ms/step - loss: 1.3171 - categorical_accuracy: 0.5725 - precision: 0.7290 - recall: 0.4159 - val_loss: 1.2103 - val_categorical_accuracy: 0.6053 - val_precision: 0.7572 - val_recall: 0.4604
# Epoch 6/30
# 1505/1505 [==============================] - 164s 109ms/step - loss: 1.2657 - categorical_accuracy: 0.5896 - precision: 0.7379 - recall: 0.4422 - val_loss: 1.1857 - val_categorical_accuracy: 0.6139 - val_precision: 0.7397 - val_recall: 0.4978
# Epoch 7/30
# 1505/1505 [==============================] - 176s 117ms/step - loss: 1.2103 - categorical_accuracy: 0.6058 - precision: 0.7475 - recall: 0.4677 - val_loss: 1.2886 - val_categorical_accuracy: 0.5855 - val_precision: 0.7120 - val_recall: 0.4430
# Epoch 8/30
# 1505/1505 [==============================] - 177s 118ms/step - loss: 1.1669 - categorical_accuracy: 0.6227 - precision: 0.7598 - recall: 0.4915 - val_loss: 1.1124 - val_categorical_accuracy: 0.6122 - val_precision: 0.7211 - val_recall: 0.5292
# Epoch 9/30
# 1505/1505 [==============================] - 162s 108ms/step - loss: 1.1275 - categorical_accuracy: 0.6312 - precision: 0.7652 - recall: 0.5079 - val_loss: 1.1013 - val_categorical_accuracy: 0.6192 - val_precision: 0.7083 - val_recall: 0.5400
# Epoch 10/30
# 1505/1505 [==============================] - 163s 108ms/step - loss: 1.0965 - categorical_accuracy: 0.6420 - precision: 0.7727 - recall: 0.5242 - val_loss: 1.0087 - val_categorical_accuracy: 0.6617 - val_precision: 0.7859 - val_recall: 0.5525
# Epoch 11/30
# 1505/1505 [==============================] - 157s 105ms/step - loss: 1.0670 - categorical_accuracy: 0.6500 - precision: 0.7754 - recall: 0.5357 - val_loss: 1.1446 - val_categorical_accuracy: 0.6087 - val_precision: 0.6815 - val_recall: 0.5401
# Epoch 12/30
# 1505/1505 [==============================] - 154s 102ms/step - loss: 1.0470 - categorical_accuracy: 0.6556 - precision: 0.7793 - recall: 0.5465 - val_loss: 1.0532 - val_categorical_accuracy: 0.6665 - val_precision: 0.7642 - val_recall: 0.5909
# Epoch 13/30
# 1505/1505 [==============================] - 161s 107ms/step - loss: 1.0170 - categorical_accuracy: 0.6660 - precision: 0.7858 - recall: 0.5583 - val_loss: 1.0565 - val_categorical_accuracy: 0.6566 - val_precision: 0.7522 - val_recall: 0.5888
# Epoch 14/30
# 1505/1505 [==============================] - 158s 105ms/step - loss: 0.9988 - categorical_accuracy: 0.6713 - precision: 0.7891 - recall: 0.5673 - val_loss: 1.1709 - val_categorical_accuracy: 0.6241 - val_precision: 0.7053 - val_recall: 0.5524
# Epoch 15/30
# 1505/1505 [==============================] - 158s 105ms/step - loss: 0.9740 - categorical_accuracy: 0.6807 - precision: 0.7957 - recall: 0.5806 - val_loss: 1.0136 - val_categorical_accuracy: 0.6735 - val_precision: 0.7683 - val_recall: 0.5868
# Epoch 16/30
# 1505/1505 [==============================] - 196s 130ms/step - loss: 0.9658 - categorical_accuracy: 0.6835 - precision: 0.7985 - recall: 0.5850 - val_loss: 1.0426 - val_categorical_accuracy: 0.6703 - val_precision: 0.7466 - val_recall: 0.6013
# Epoch 17/30
# 1505/1505 [==============================] - 175s 116ms/step - loss: 0.9445 - categorical_accuracy: 0.6894 - precision: 0.7998 - recall: 0.5920 - val_loss: 0.9998 - val_categorical_accuracy: 0.6775 - val_precision: 0.7870 - val_recall: 0.6066
# Epoch 18/30
# 1505/1505 [==============================] - 177s 117ms/step - loss: 0.9358 - categorical_accuracy: 0.6923 - precision: 0.8017 - recall: 0.5983 - val_loss: 1.2196 - val_categorical_accuracy: 0.6001 - val_precision: 0.6691 - val_recall: 0.5443
# Epoch 19/30
# 1505/1505 [==============================] - 162s 108ms/step - loss: 0.9287 - categorical_accuracy: 0.6923 - precision: 0.8029 - recall: 0.5984 - val_loss: 1.0826 - val_categorical_accuracy: 0.6436 - val_precision: 0.7300 - val_recall: 0.5729
# Epoch 20/30
# 1505/1505 [==============================] - 160s 106ms/step - loss: 0.9147 - categorical_accuracy: 0.6998 - precision: 0.8059 - recall: 0.6083 - val_loss: 1.2407 - val_categorical_accuracy: 0.5960 - val_precision: 0.6831 - val_recall: 0.5262
# Epoch 21/30
# 1505/1505 [==============================] - 158s 105ms/step - loss: 0.9004 - categorical_accuracy: 0.7016 - precision: 0.8069 - recall: 0.6130 - val_loss: 0.9975 - val_categorical_accuracy: 0.6855 - val_precision: 0.7691 - val_recall: 0.6223
# Epoch 22/30
# 1505/1505 [==============================] - 155s 103ms/step - loss: 0.8831 - categorical_accuracy: 0.7104 - precision: 0.8120 - recall: 0.6220 - val_loss: 0.9753 - val_categorical_accuracy: 0.6764 - val_precision: 0.7645 - val_recall: 0.6199
# Epoch 23/30
# 1505/1505 [==============================] - 150s 100ms/step - loss: 0.8905 - categorical_accuracy: 0.7072 - precision: 0.8104 - recall: 0.6210 - val_loss: 0.9310 - val_categorical_accuracy: 0.6968 - val_precision: 0.7883 - val_recall: 0.6411
# Epoch 24/30
# 1505/1505 [==============================] - 150s 100ms/step - loss: 0.8707 - categorical_accuracy: 0.7110 - precision: 0.8131 - recall: 0.6252 - val_loss: 1.0652 - val_categorical_accuracy: 0.6547 - val_precision: 0.7439 - val_recall: 0.6012
# Epoch 25/30
# 1505/1505 [==============================] - 156s 104ms/step - loss: 0.8675 - categorical_accuracy: 0.7148 - precision: 0.8155 - recall: 0.6273 - val_loss: 1.1043 - val_categorical_accuracy: 0.6306 - val_precision: 0.7201 - val_recall: 0.5809
# Epoch 26/30
# 1505/1505 [==============================] - 156s 104ms/step - loss: 0.8529 - categorical_accuracy: 0.7176 - precision: 0.8160 - recall: 0.6331 - val_loss: 0.7886 - val_categorical_accuracy: 0.7425 - val_precision: 0.8273 - val_recall: 0.6746
# Epoch 27/30
# 1505/1505 [==============================] - 155s 103ms/step - loss: 0.8494 - categorical_accuracy: 0.7193 - precision: 0.8177 - recall: 0.6363 - val_loss: 1.0371 - val_categorical_accuracy: 0.6528 - val_precision: 0.7374 - val_recall: 0.5909
# Epoch 28/30
# 1505/1505 [==============================] - 157s 104ms/step - loss: 0.8426 - categorical_accuracy: 0.7219 - precision: 0.8188 - recall: 0.6406 - val_loss: 1.2683 - val_categorical_accuracy: 0.6141 - val_precision: 0.6756 - val_recall: 0.5549
# Epoch 29/30
# 1505/1505 [==============================] - 157s 104ms/step - loss: 0.8248 - categorical_accuracy: 0.7272 - precision: 0.8234 - recall: 0.6475 - val_loss: 1.3712 - val_categorical_accuracy: 0.6157 - val_precision: 0.6782 - val_recall: 0.5561
# Epoch 30/30
# 1505/1505 [==============================] - 168s 112ms/step - loss: 0.8219 - categorical_accuracy: 0.7292 - precision: 0.8247 - recall: 0.6489 - val_loss: 1.2573 - val_categorical_accuracy: 0.6063 - val_precision: 0.6763 - val_recall: 0.5590
# 502/502 [==============================] - 14s 28ms/step - loss: 1.2573 - categorical_accuracy: 0.6063 - precision: 0.6763 - recall: 0.5590 2s - loss: 1.2531 - categorical_accuracy: 0.6
# Evaluating validation metrics
# 	loss: 1.2573
# 	categorical_accuracy: 0.6063
# 	precision: 0.6763
# 	recall: 0.5590
# 0.6112565445026178
